# %%
import googlemaps
#allows us to access googlemaps api
gmaps = googlemaps.Client(key='AIzaSyD3DeaatuQqGlFZTgKEpX7G9l-LH85Ky1k')
#from googlempas, use the client key to show we are authorized to pull information
geocode_result = gmaps.geocode('Sacramento, CA')
#query for the api(where you want to search)

# %%
from googlemaps.places import places_autocomplete_session_token
#allows for auto complete on querys(will finish)
key = 'AIzaSyD3DeaatuQqGlFZTgKEpX7G9l-LH85Ky1k'
#api key
client = googlemaps.Client(key)
#declares who we are pulling from and we have access
location = (geocode_result[0]['geometry']['location']['lat'], geocode_result[0]['geometry']['location']['lng'])
#declaring what locational data(from geocode, pull geometry, from geometry pull location, pull lat from location) and then do same thing for lng
ty = 'gym'
#what type of business are you looking for
language = 'english'
radius = 1000
#search radius from geocode_result input

# %%
schools = gmaps.places_nearby(location=location, keyword='pizza', open_now=True,
                                  rank_by='distance', type=ty)
#places_nearby allows us to pull from neighboring businesses that are close to the user input location specified in the first kernel
#location is our inputed location
#open_now shows only stores that are currenlty open at the time of the query
#rank_by specifies how the ouput will be ordered
#type = ty pulls from what desired business category the user is looking for

# %%
import pandas as pd
#dataframe organizer
import numpy as np
name = []
lat = []
lng = []
#set as list
for i in schools.get('results'):
    name.append(i['name'])
    lat.append(i['geometry']['location']['lat'])
    lng.append(i['geometry']['location']['lng'])
#for these specific results within schools, filter out name, lat, lng 
#for loop allows for same code applied to each result
schoolsDf = pd.DataFrame({"name": name, "lat": lat, "lng": lng})
#assigning names to column titles corresponding to for loop data list
schoolsDf
#print schoolsDf
# Out:
#                                          name        lat         lng
# 0                   California Family Fitness  38.578718 -121.493504
# 1   Sacramento Pipeworks Climbing and Fitness  38.589047 -121.481278
# 2                   California Family Fitness  38.563927 -121.467464
# 3                   California Family Fitness  38.584190 -121.416216
# 4                              Planet Fitness  38.528247 -121.446029
# 5                   California Family Fitness  38.514492 -121.522873
# 6                   California Family Fitness  38.496520 -121.507169
# 7                              Planet Fitness  38.608358 -121.381504
# 8                              Planet Fitness  38.475631 -121.431587
# 9                              Planet Fitness  38.675446 -121.384265
# 10                             Planet Fitness  38.589413 -121.305379
# 11      Technique Gymnastics Tumbling & Dance  38.611857 -121.257906
